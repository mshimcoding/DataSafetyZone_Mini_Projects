# %%
import pandas as pd

# %%
df = pd.read_csv("purchase.csv")
df.head()
## df
# Out:
#                                              Address    Lot AM or PM  \
# 0  16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1  9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                   Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3              7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4  23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
#
#                                         Browser Info  \
# 0  Opera/9.56.(X11; Linux x86_64; sl-SI) Presto/2...
# 1  Opera/8.93.(Windows 98; Win 9x 4.90; en-US) Pr...
# 2  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
# 3  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_0 ...
# 4  Opera/9.58.(X11; Linux x86_64; it-IT) Presto/2...
#
#                            Company       Credit Card CC Exp Date  \
# 0                  Martinez-Herman  6011929061123406       02/20
# 1  Fletcher, Richards and Whitaker  3337758169645356       11/18
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Address           10000 non-null  object
#  1   Lot               10000 non-null  object
#  2   AM or PM          10000 non-null  object
#  3   Browser Info      10000 non-null  object
#  4   Company           10000 non-null  object
#  5   Credit Card       10000 non-null  object
#  6   CC Exp Date       10000 non-null  object
#  7   CC Security Code  10000 non-null  object
#  8   CC Provider       10000 non-null  object
#  9   Email             10000 non-null  object
#  10  Job               10000 non-null  object
#  11  IP Address        10000 non-null  object
#  12  Language          10000 non-null  object
#  13  Purchase Price    10000 non-null  float64
# dtypes: float64(1), object(13)
# memory usage: 1.1+ MB

# %% [markdown]
# Use isnull to check even bigger db

# %%
df['Credit Card'] = df['Credit Card'].astype(str)
df['CC Security Code'] = df['CC Security Code'].astype(str)

# %% [markdown]
# 1. total purchase avg
#
# 2. how many used english
#
# 3. job of users
#
# 4. what jobs used most $
#
# 5. what job purchsed most frequently
#
# 6. bondellen@williams-garza.com used how much?
#
# 7. MasterCard and purchased something more than 50$
#
# 8. how many used Windows
#
# 9. % of users what used Windows, Linux, Mac

# %% [markdown]
# 1.

# %%
df.describe()
df['Purchase Price'].mean()
# Out:
# 50.34730200000025

# %%
df['Purchase Price'].max()
# Out:
# 99.99

# %%
df['Purchase Price'].describe()
# Out:
# count    10000.000000
# mean        50.347302
# std         29.015836
# min          0.000000
# 25%         25.150000
# 50%         50.505000
# 75%         75.770000
# max         99.990000
# Name: Purchase Price, dtype: float64

# %% [markdown]
# 2.

# %%
df.groupby('Language')['Purchase Price'].count()
# Out:
# Language
# de    1155
# el    1137
# en    1098
# es    1095
# fr    1097
# it    1086
# pt    1118
# ru    1155
# zh    1059
# Name: Purchase Price, dtype: int64

# %%
df['Language'].unique()
# Out:
# array(['el', 'fr', 'de', 'es', 'ru', 'pt', 'zh', 'en', 'it'], dtype=object)

# %% [markdown]
# 3.

# %%
len(df['Job'].unique())
df['Job'].nunique()
# Out:
# 623

# %% [markdown]
# 4.

# %%
df.groupby('Job')['Purchase Price'].sum().sort_values(ascending=False)
# Out:
# Job
# Dietitian                      1605.30
# Lawyer                         1603.85
# Purchasing manager             1577.97
# Therapist, art                 1526.31
# Clinical cytogeneticist        1495.92
#                                 ...
# Music therapist                 327.50
# Actuary                         262.72
# Information systems manager     241.42
# Marketing executive             234.08
# Art gallery manager             219.05
# Name: Purchase Price, Length: 623, dtype: float64

# %%
df.groupby('Job')['Purchase Price'].sum().sort_values(ascending=False)[:10]
# Out:
# Job
# Dietitian                            1605.30
# Lawyer                               1603.85
# Purchasing manager                   1577.97
# Therapist, art                       1526.31
# Clinical cytogeneticist              1495.92
# Research officer, political party    1488.79
# Designer, jewellery                  1482.20
# Interior and spatial designer        1466.20
# Network engineer                     1421.73
# Social researcher                    1416.34
# Name: Purchase Price, dtype: float64

# %% [markdown]
# 5.

# %%
df['Job'].value_counts()
# Out:
# Interior and spatial designer        31
# Lawyer                               30
# Social researcher                    28
# Research officer, political party    27
# Designer, jewellery                  27
#                                      ..
# Stage manager                         7
# Editor, film/video                    6
# Actuary                               6
# Investment analyst                    5
# Information systems manager           5
# Name: Job, Length: 623, dtype: int64

# %% [markdown]
# 6.

# %%
df[df['Email']=='bondellen@williams-garza.com']
df[df['Email'].str.lower() =='bondellen@williams-garza.com']
# Out:
#                                                 Address    Lot AM or PM  \
# 1234  2470 Maria Manors Suite 185\nJoneshaven, MN 87251  82 UX       PM
#
#                                            Browser Info  \
# 1234  Mozilla/5.0 (X11; Linux x86_64; rv:1.9.5.20) G...
#
#                     Company       Credit Card CC Exp Date CC Security Code  \
# 1234  Cole, King and Bowers  4926535242672853       09/21              188
#
#            CC Provider                         Email  \
# 1234  American Express  bondellen@williams-garza.com
#
#                                     Job    IP Address Language  Purchase Price
# 1234  Planning and development surveyor  159.182.3.50       ru           77.88

# %% [markdown]
# 7.

# %%
df.loc[(df['Purchase Price']>= 50) & (df['CC Provider'] == 'Mastercard')]
# Out:
#                                                 Address    Lot AM or PM  \
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 18    461 Christopher Square\nWest Michaelchester, C...  17 SB       PM
# 31                     USNS Alvarado\nFPO AA 27052-1231  26 Lh       PM
# 35    93392 Webb Gardens Apt. 220\nLaurabury, AR 999...  37 om       AM
# 90          431 Bowen Lights\nFergusonborough, MH 01362  31 tG       AM
# ...                                                 ...    ...      ...
# 9941           43757 Brown Lodge\nValerieberg, PR 88518  68 DG       AM
# 9948  95544 Johnson Isle Suite 939\nMichaelberg, RI ...  91 bW       AM
# 9954  051 Samantha Wells Apt. 328\nScottborough, OR ...  11 vG       AM
# 9981  087 Larson Roads Apt. 587\nRicestad, WI 98077-...  95 Kw       AM
# 9987     2754 Klein Mission\nJohnsonview, PA 64925-9624  65 Fg       PM
#
#                                            Browser Info  \
# ...

# %% [markdown]
# Enligh always beware lol

# %%
df.loc[(df['Purchase Price']>= 50) & (df['CC Provider'].str.lower() == 'mastercard')]
# Out:
#                                                 Address    Lot AM or PM  \
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 18    461 Christopher Square\nWest Michaelchester, C...  17 SB       PM
# 31                     USNS Alvarado\nFPO AA 27052-1231  26 Lh       PM
# 35    93392 Webb Gardens Apt. 220\nLaurabury, AR 999...  37 om       AM
# 90          431 Bowen Lights\nFergusonborough, MH 01362  31 tG       AM
# ...                                                 ...    ...      ...
# 9941           43757 Brown Lodge\nValerieberg, PR 88518  68 DG       AM
# 9948  95544 Johnson Isle Suite 939\nMichaelberg, RI ...  91 bW       AM
# 9954  051 Samantha Wells Apt. 328\nScottborough, OR ...  11 vG       AM
# 9981  087 Larson Roads Apt. 587\nRicestad, WI 98077-...  95 Kw       AM
# 9987     2754 Klein Mission\nJohnsonview, PA 64925-9624  65 Fg       PM
#
#                                            Browser Info  \
# ...

# %%
len(df.loc[(df['Purchase Price']>= 50) & (df['CC Provider'].str.lower() == 'mastercard')])
# Out:
# 405

# %% [markdown]
# 8.

# %%
df.groupby('Browser Info')['Purchase Price'].count()
# Out:
# Browser Info
# Mozilla/5.0 (Macintosh; Intel Mac OS X 10_5_0 rv:2.0; sl-SI) AppleWebKit/533.25.6 (KHTML, like Gecko) Version/4.0 Safari/533.25.6      1
# Mozilla/5.0 (Macintosh; Intel Mac OS X 10_5_0 rv:4.0; en-US) AppleWebKit/535.34.7 (KHTML, like Gecko) Version/5.0 Safari/535.34.7      1
# Mozilla/5.0 (Macintosh; Intel Mac OS X 10_5_0 rv:5.0; sl-SI) AppleWebKit/532.10.4 (KHTML, like Gecko) Version/5.0.2 Safari/532.10.4    1
# Mozilla/5.0 (Macintosh; Intel Mac OS X 10_5_0 rv:6.0; en-US) AppleWebKit/533.45.4 (KHTML, like Gecko) Version/4.1 Safari/533.45.4      1
# Mozilla/5.0 (Macintosh; Intel Mac OS X 10_5_0) AppleWebKit/5321 (KHTML, like Gecko) Chrome/14.0.824.0 Safari/5321                      1
#                                                                                                                                       ..
# Opera/9.99.(X11; Linux i686; sl-SI) Presto/2.9.186 Version/12.00                                                                       1
# ...

# %%
answer8 = df[df["Browser Info"].str.contains('Windows')]

answer8 = df[df["Browser Info"].str.lower().str.contains('windows')]

answer8
# Out:
#                                                 Address    Lot AM or PM  \
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                      Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 6        93971 Conway Causeway\nAndersonburgh, AZ 75107  96 Xt       AM
# 14    8774 Jason Keys Suite 427\nEast Scottborough, ...  70 zH       AM
# 15       31730 Chelsea Crest\nBlakemouth, CT 90395-0620  41 Cj       PM
# ...                                                 ...    ...      ...
# 9988      0154 Green Forest\nNew Timothy, IL 33670-4620  11 MC       AM
# 9989         5674 Cruz Trace\nNew Shelby, KY 51047-5469  12 Kf       AM
# 9991              PSC 8165, Box 8498\nAPO AP 60327-0346  50 dA       AM
# 9995      966 Castaneda Locks\nWest Juliafurt, CO 96415  92 XI       PM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
#
#                                            Browser Info  \
# ...

# %% [markdown]
# 9.

# %%
windows = df[df["Browser Info"].str.lower().str.contains('windows')]
linux = df[df["Browser Info"].str.lower().str.contains('linux')]
mac = df[df["Browser Info"].str.lower().str.contains('mac')]

print(len(windows) / len(df))
print(len(linux) / len(df))
print(len(mac) / len(df))

print(len(windows) + len(linux) + len(mac))
# Out:
# 0.4994
# 0.2322
# 0.2684
# 10000
